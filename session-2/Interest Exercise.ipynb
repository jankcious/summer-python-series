# %% [markdown]
# 20 years
# 3% annual return

# %%
years = 20
return_rate = .03
start = 100
for i in range(20):
    print('Year:', i, '$', start)
    start = start * (return_rate) + start
    

print('Final Answer:', start)
# Out:
# Year: 0 $ 100
# Year: 1 $ 103.0
# Year: 2 $ 106.09
# Year: 3 $ 109.2727
# Year: 4 $ 112.550881
# Year: 5 $ 115.92740743
# Year: 6 $ 119.4052296529
# Year: 7 $ 122.987386542487
# Year: 8 $ 126.67700813876161
# Year: 9 $ 130.47731838292447
# Year: 10 $ 134.3916379344122
# Year: 11 $ 138.42338707244454
# Year: 12 $ 142.57608868461787
# Year: 13 $ 146.8533713451564
# Year: 14 $ 151.2589724855111
# Year: 15 $ 155.79674166007644
# Year: 16 $ 160.47064390987873
# Year: 17 $ 165.2847632271751
# Year: 18 $ 170.24330612399035
# Year: 19 $ 175.35060530771005
# Final Answer: 180.61112346694136

# %% [markdown]
# mean = 6%
#
# std = 10%
#
# normally distibuted
#
# start at $100

# %%
mean = .06
std = .1
start = 100

# %%
import random

# %%
random.gauss(mean, std)
# Out:
# -0.010817627842061792

# %%
return_rate = .03
start = 100
ans = []
for x in range(10000):
    start = 100
    for i in range(1, 21):
        rate = random.gauss(mean, std)
        start = start * (rate) + start
        #print('Year:', i, ', $', start, ', rate = ', rate)
    ans.append(start)
    #print('Final Answer:', start)

for x in ans:
    print(x)
# Out:
# 239.47871351469155
# 198.65690987675288
# 297.79016362956577
# 224.7152627477383
# 276.00421253692986
# 132.6661939994697
# 301.1827956543681
# 449.0496404372289
# 379.43830060905043
# 276.6311259730976
# 116.72241527830658
# 136.30324976558396
# 120.69617033663539
# 302.58351999328295
# 108.16648003309888
# 479.29531451151934
# 251.1897686511217
# 386.3019177272841
# 241.77013708463676
# 253.5890844258349
# 315.1171654788933
# 469.285076695377
# 239.0044388588668
# 201.27847675202798
# 379.5304903376121
# 238.01728180450834
# 196.13123467082647
# 200.71299985270537
# 403.2290008292752
# 183.1500536181259
# 317.16127296690865
# 359.3409920046665
# 169.74906177893354
# 355.0123288658419
# 684.6319556250132
# 315.6857258992753
# 479.72421400606953
# 251.59721493368707
# 980.4305979702879
# 164.68984903457746
# 180.36737423560928
# 230.90658238959122
# 461.8537278801271
# 434.2395610019911
# 463.5875676810638
# 686.383473480571
# 461.8915889019504
# 148.00982590062878
# ...

# %%
sum(ans)/len(ans)
# Out:
# 318.9268838717641
